# %% [markdown]
# # 01 Data Engine
# Build a tiny data pipeline: load text, inspect tokens, and create train/val splits.

# %%
from pathlib import Path
data_path = Path('../data')
print('Data folder:', data_path.resolve())
