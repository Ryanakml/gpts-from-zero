# %% [markdown]
# # 03 Building The Brain
# Assemble a tiny GPT model and run a first forward pass.

# %%
from src.model import GPTConfig, TinyGPT

cfg = GPTConfig()
model = TinyGPT(cfg)
print('Parameters:', sum(p.numel() for p in model.parameters()))
